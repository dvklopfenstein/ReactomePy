# %% [markdown]
# # Which molecules participate in _Interleukin-4 and 13 signaling_ (R-HSA-6785807)?
#
# From Figure 4a in [_**Reactome graph database: Efficient access to complex pathway data**_](https://journals.plos.org/ploscompbiol/article?rev=2&id=10.1371/journal.pcbi.1005968)
#
#
# ## Step 1) [Connect to Neo4j loaded with the Reactome Knowledgebase](https://github.com/dvklopfenstein/reactome_neo4j_py/blob/master/doc/md/README_gdbdr.md)

# %%
from neo4j import GraphDatabase

neo4j_url = 'bolt://localhost:7687'
neo4j_usr = 'neo4j'
neo4j_password = 'myneo4j_password'

gdbdr = GraphDatabase.driver(neo4j_url, auth=(neo4j_usr, neo4j_password))

# %% [markdown]
# ## Step 2) Pathway Molecules Query
# ### Which molecules participate in _Interleukin-4 and 13 signaling_ (R-HSA-6785807)?

# %%
## Step 2) Pathway Molecules Query

query = ('MATCH (p:Pathway{stId:"R-HSA-6785807"})-[:hasEvent*]->(rle:ReactionLikeEvent), '
         '(rle)-[:'
         'input|output|catalystActivity|regulatedBy|'
         'hasComponent|hasMember|hasCandidate|'
         'entityFunctionalStatus|physicalEntity|'
         'regulator|repeatedUnit'
         '*]->(pe:PhysicalEntity), '
         '(pe)-[:referenceEntity]->(re:ReferenceEntity)-[:referenceDatabase]->(rd:ReferenceDatabase) '
         'RETURN DISTINCT pe.displayName AS Name, re.identifier AS Identifier, rd.displayName AS Database')

# Query and get the sub-pathways under R-HSA-983169
def _get_data():
    with gdbdr.session() as session:
        return session.run(query).data()

data = _get_data()

# %% [markdown]
# ## Step 3) Print Data

# %%
# Print sub-pathways under R-HSA-983169
print('{N} molecules participate in "Interleukin-4 and 13 signaling":\n'.format(N=len(data)))
print('Database| ID              | Name')
print('--------|-----------------|--------------------------')
for data in sorted(data, key=lambda r:[r['Database'], r['Name']]):
    print("{Database:8}| {Identifier:15} | {Name}".format(**data))
# Out:
# 228 molecules participate in "Interleukin-4 and 13 signaling":
#
# Database| ID              | Name
# --------|-----------------|--------------------------
# ChEBI   | 456216          | ADP [cytosol]
# ChEBI   | 30616           | ATP [cytosol]
# ENSEMBL | ENSG00000142208 | AKT1 gene [nucleoplasm]
# ENSEMBL | ENSG00000161905 | ALOX15 gene [nucleoplasm]
# ENSEMBL | ENSG00000012779 | ALOX5 gene [nucleoplasm]
# ENSEMBL | ENSG00000135046 | ANXA1 gene [nucleoplasm]
# ENSEMBL | ENSG00000156127 | BATF gene [nucleoplasm]
# ENSEMBL | ENSG00000171791 | BCL2 gene [nucleoplasm]
# ENSEMBL | ENSG00000171552 | BCL2L1 gene [nucleoplasm]
# ENSEMBL | ENSG00000113916 | BCL6 gene [nucleoplasm]
# ENSEMBL | ENSG00000089685 | BIRC5 gene [nucleoplasm]
# ENSEMBL | ENSG00000172156 | CCL11 gene [nucleoplasm]
# ENSEMBL | ENSG00000108691 | CCL2 gene [nucleoplasm]
# ENSEMBL | ENSG00000102962 | CCL22 gene [nucleoplasm]
# ENSEMBL | ENSG00000110092 | CCND1 gene [nucleoplasm]
# ENSEMBL | ENSG00000135218 | CD36 gene [nucleoplasm]
# ENSEMBL | ENSG00000124762 | CDKN1A gene [nucleoplasm]
# ENSEMBL | ENSG00000221869 | CEBPD gene [nucleoplasm]
# ENSEMBL | ENSG00000164692 | COL1A2 gene [nucleoplasm]
# ENSEMBL | ENSG00000124491 | F13A1 gene [nucleoplasm]
# ENSEMBL | ENSG00000117560 | FASLG gene [nucleoplasm]
# ENSEMBL | ENSG00000104921 | FCER2 gene [nucleoplasm]
# ENSEMBL | ENSG00000138685 | FGF2 gene [nucleoplasm]
# ENSEMBL | ENSG00000115414 | FN1 gene [nucleoplasm]
# ENSEMBL | ENSG00000170345 | FOS gene [nucleoplasm]
# ENSEMBL | ENSG00000150907 | FOXO1 gene [nucleoplasm]
# ENSEMBL | ENSG00000118689 | FOXO3 gene [nucleoplasm]
# ENSEMBL | ENSG00000075618 | FSCN1 gene [nucleoplasm]
# ENSEMBL | ENSG00000107485 | GATA3 gene [nucleoplasm]
# ENSEMBL | ENSG00000019991 | HGF gene [nucleoplasm]
# ENSEMBL | ENSG00000100644 | HIF1A gene [nucleoplasm]
# ENSEMBL | ENSG00000100292 | HMOX1 gene [nucleoplasm]
# ENSEMBL | ENSG00000080824 | HSP90AA1 gene [nucleoplasm]
# ENSEMBL | ENSG00000109971 | HSPA8 gene [nucleoplasm]
# ENSEMBL | ENSG00000090339 | ICAM1 gene [nucleoplasm]
# ENSEMBL | ENSG00000211891 | IGHE gene [nucleoplasm]
# ENSEMBL | ENSG00000211896 | IGHG1 gene [nucleoplasm]
# ENSEMBL | ENSG00000211892 | IGHG4 gene [nucleoplasm]
# ENSEMBL | ENSG00000136634 | IL10 gene [nucleoplasm]
# ENSEMBL | ENSG00000168811 | IL12A gene [nucleoplasm]
# ENSEMBL | ENSG00000113302 | IL12B gene [nucleoplasm]
# ENSEMBL | ENSG00000112115 | IL17A gene [nucleoplasm]
# ENSEMBL | ENSG00000112116 | IL17F gene [nucleoplasm]
# ENSEMBL | ENSG00000150782 | IL18 gene [nucleoplasm]
# ENSEMBL | ENSG00000115008 | IL1A gene [nucleoplasm]
# ENSEMBL | ENSG00000125538 | IL1B gene [nucleoplasm]
# ENSEMBL | ENST00000619177 | IL23A gene [nucleoplasm]
# ENSEMBL | ENSG00000162594 | IL23R gene [nucleoplasm]
# ENSEMBL | ENSG00000077238 | IL4R gene [nucleoplasm]
# ENSEMBL | ENSG00000136244 | IL6 gene [nucleoplasm]
# ENSEMBL | ENSG00000160712 | IL6R gene [nucleoplasm]
# ENSEMBL | ENSG00000169429 | IL8 gene [nucleoplasm]
# ENSEMBL | ENSG00000137265 | IRF4 gene [nucleoplasm]
# ENSEMBL | ENSG00000169896 | ITGAM gene [nucleoplasm]
# ENSEMBL | ENSG00000140678 | ITGAX gene [nucleoplasm]
# ENSEMBL | ENSG00000150093 | ITGB1 Gene [nucleoplasm]
# ENSEMBL | ENSG00000160255 | ITGB2  gene [nucleoplasm]
# ENSEMBL | ENSG00000171223 | JUNB gene [nucleoplasm]
# ENSEMBL | ENSG00000130702 | LAMA5 gene [nucleoplasm]
# ENSEMBL | ENSG00000129988 | LBP gene [nucleoplasm]
# ENSEMBL | ENSG00000148346 | LCN2 gene [nucleoplasm]
# ENSEMBL | ENSG00000128342 | LIF gene [nucleoplasm]
# ENSEMBL | ENSG00000189221 | MAOA gene [nucleoplasm]
# ENSEMBL | ENSG00000143384 | MCL1 gene [nucleoplasm]
# ENSEMBL | ENSG00000196611 | MMP1 gene [nucleoplasm]
# ENSEMBL | ENSG00000087245 | MMP2 gene [nucleoplasm]
# ENSEMBL | ENSG00000149968 | MMP3 gene [nucleoplasm]
# ENSEMBL | ENSG00000100985 | MMP9 gene [nucleoplasm]
# ENSEMBL | ENSG00000185499 | MUC1 gene [nucleoplasm]
# ENSEMBL | ENSG00000136997 | MYC gene [nucleoplasm]
# ENSEMBL | ENSG00000111704 | NANOG gene [nucleoplasm]
# ENSEMBL | ENSG00000182636 | NDN gene [nucleoplasm]
# ENSEMBL | ENSG00000007171 | NOS2 gene [nucleoplasm]
# ENSEMBL | ENSG00000116329 | OPRD1 gene [nucleoplasm]
# ENSEMBL | ENSG00000112038 | OPRM1 gene [nucleoplasm]
# ENSEMBL | ENSG00000099985 | OSM gene [nucleoplasm]
# ENSEMBL | ENSG00000145675 | PIK3R1 gene [nucleoplasm]
# ENSEMBL | ENSG00000137193 | PIM1 gene [nucleoplasm]
# ENSEMBL | ENSG00000115138 | POMC gene [nucleoplasm]
# ENSEMBL | ENSG00000143190 | POU2F1 gene [nucleoplasm]
# ENSEMBL | ENSG00000073756 | PTGS2 gene [nucleoplasm]
# ENSEMBL | ENSG00000116574 | RHOU gene [nucleoplasm]
# ENSEMBL | ENSG00000069667 | RORA gene [nucleoplasm]
# ENSEMBL | ENSG00000143365 | RORC gene [nucleoplasm]
# ENSEMBL | ENSG00000170989 | S1PR1 gene [nucleoplasm]
# ENSEMBL | ENSG00000173432 | SAA1 gene [nucleoplasm]
# ENSEMBL | ENSG00000185338 | SOCS1 gene [nucleoplasm]
# ENSEMBL | ENSG00000184557 | SOCS3 gene [nucleoplasm]
# ENSEMBL | ENSG00000181449 | SOX2 gene [nucleoplasm]
# ENSEMBL | ENSG00000115415 | STAT1 gene [nucleoplasm]
# ENSEMBL | ENSG00000105329 | TGFB1 gene [nucleoplasm]
# ENSEMBL | ENSG00000102265 | TIMP1 gene [nucleoplasm]
# ENSEMBL | ENSG00000232810 | TNF gene [nucleoplasm]
# ENSEMBL | ENSG00000028137 | TNFRSF1B gene [nucleoplasm]
# ENSEMBL | ENSG00000141510 | TP53 gene [nucleoplasm]
# ENSEMBL | ENSG00000122691 | TWIST1 gene [nucleoplasm]
# ENSEMBL | ENSG00000162692 | VCAM1 gene [nucleoplasm]
# ENSEMBL | ENSG00000112715 | VEGFA gene [nucleoplasm]
# ENSEMBL | ENSG00000026025 | VIM gene [nucleoplasm]
# ENSEMBL | ENSG00000148516 | ZEB1 gene [nucleoplasm]
# Guide to Pharmacology| 8912            | acalabrutinib [cytosol]
# Guide to Pharmacology| 7792            | baricitinib [cytosol]
# Guide to Pharmacology| 6912            | ibrutinib [cytosol]
# Guide to Pharmacology| 5688            | ruxolitinib [cytosol]
# Guide to Pharmacology| 5677            | tofacitinib [cytosol]
# UniProt | P16671          | 4xPalmC-CD36 [plasma membrane]
# UniProt | P31749          | AKT1 [cytosol]
# UniProt | P16050          | ALOX15 [cytosol]
# UniProt | P09917          | ALOX5 [cytosol]
# UniProt | P04083          | ANXA1 [extracellular region]
# UniProt | Q16520          | BATF [nucleoplasm]
# UniProt | P10415          | BCL2 [mitochondrial outer membrane]
# UniProt | Q07817          | BCL2L1 [mitochondrial outer membrane]
# UniProt | P41182          | BCL6 [nucleoplasm]
# UniProt | O15392          | BIRC5 [nucleoplasm]
# UniProt | P51671          | CCL11 [extracellular region]
# UniProt | P13500          | CCL2 [extracellular region]
# UniProt | O00626          | CCL22(25-93) [extracellular region]
# UniProt | P24385          | CCND1 [nucleoplasm]
# UniProt | P38936          | CDKN1A [cytosol]
# UniProt | P49716          | CEBPD [nucleoplasm]
# UniProt | P08123          | COL1A2 [extracellular region]
# UniProt | P48023          | FASLG(1-281) [extracellular region]
# UniProt | P06734          | FCER2(1-321) [plasma membrane]
# UniProt | P09038          | FGF2(10-155) [extracellular region]
# UniProt | P02751          | FN1(32-2386) [extracellular region]
# UniProt | P01100          | FOS [nucleoplasm]
# UniProt | Q12778          | FOXO1 [nucleoplasm]
# UniProt | O43524          | FOXO3 [nucleoplasm]
# UniProt | Q16658          | FSCN1 [cytosol]
# UniProt | P23771          | GATA3 [nucleoplasm]
# UniProt | P14210          | HGF(32-494) [extracellular region]
# UniProt | Q16665          | HIF1A [nucleoplasm]
# UniProt | P09601          | HMOX1 [endoplasmic reticulum membrane]
# UniProt | P07900          | HSP90AA1 [cytosol]
# UniProt | P14625          | HSP90B1 [endoplasmic reticulum lumen]
# UniProt | P11142          | HSPA8 [cytosol]
# UniProt | P05362          | ICAM1 [plasma membrane]
# UniProt | P01854          | IGHE [extracellular region]
# UniProt | P01857          | IGHG1 [extracellular region]
# UniProt | P01861          | IGHG4 [extracellular region]
# UniProt | P22301          | IL10 [extracellular region]
# UniProt | P29459          | IL12A [extracellular region]
# UniProt | P29460          | IL12B [extracellular region]
# UniProt | P35225          | IL13 [extracellular region]
# UniProt | P78552          | IL13RA1 [plasma membrane]
# UniProt | Q14627          | IL13RA2 [extracellular region]
# UniProt | Q16552          | IL17A [extracellular region]
# UniProt | Q96PD4          | IL17F [extracellular region]
# UniProt | Q14116          | IL18(1-193) [cytosol]
# UniProt | P01584          | IL1B [extracellular region]
# UniProt | Q9NPF7          | IL23A [extracellular region]
# UniProt | Q5VWK5          | IL23R [plasma membrane]
# UniProt | P31785          | IL2RG [plasma membrane]
# UniProt | P05112          | IL4 [extracellular region]
# UniProt | P24394          | IL4R [plasma membrane]
# UniProt | P05231          | IL6 [extracellular region]
# UniProt | P08887          | IL6R [plasma membrane]
# UniProt | P10145          | IL8 [extracellular region]
# UniProt | Q15306          | IRF4 [cytosol]
# UniProt | P11215          | ITGAM [plasma membrane]
# UniProt | P20702          | ITGAX [plasma membrane]
# UniProt | P05556          | ITGB1 [plasma membrane]
# UniProt | P05107          | ITGB2 [plasma membrane]
# UniProt | P23458          | JAK1 [cytosol]
# UniProt | O60674          | JAK2 [cytosol]
# UniProt | P52333          | JAK3 [cytosol]
# UniProt | P17275          | JUNB [nucleoplasm]
# UniProt | O15230          | LAMA5 [extracellular region]
# UniProt | P18428          | LBP [extracellular region]
# UniProt | P80188          | LCN2 [extracellular region]
# UniProt | P15018          | LIF [extracellular region]
# UniProt | P21397          | MAOA [mitochondrial outer membrane]
# UniProt | Q07820          | MCL1 [cytosol]
# UniProt | P03956          | MMP1(84-469) [extracellular region]
# UniProt | P08253          | MMP2(110-660) [extracellular region]
# UniProt | P08254          | MMP3(100-477) [extracellular region]
# UniProt | P14780          | MMP9(107-707) [extracellular region]
# UniProt | P15941          | MUC1(24-1255) [plasma membrane]
# UniProt | P01106          | MYC [nucleoplasm]
# UniProt | P01583          | Myr82K-Myr83K-IL1A [extracellular region]
# UniProt | Q9H9S0          | NANOG [nucleoplasm]
# UniProt | Q99608          | NDN [nucleoplasm]
# UniProt | P35228          | NOS2 [cytosol]
# UniProt | P41143          | OPRD1 [plasma membrane]
# UniProt | P35372          | OPRM1 [plasma membrane]
# UniProt | P13725          | OSM [extracellular region]
# UniProt | P27986          | PIK3R1 [cytosol]
# UniProt | P11309          | PIM1 [nucleoplasm]
# UniProt | P01189          | POMC(138-176) [extracellular region]
# UniProt | P14859          | POU2F1 [nucleoplasm]
# UniProt | P35354          | PTGS2 [endoplasmic reticulum membrane]
# UniProt | Q7L0Q8          | RHOU [cytosol]
# UniProt | P35398          | RORA [nucleoplasm]
# UniProt | P51449          | RORC [nucleoplasm]
# UniProt | P21453          | S1PR1 [plasma membrane]
# UniProt | P0DJI8          | SAA1(19-122) [extracellular region]
# UniProt | O15524          | SOCS1 [cytosol]
# UniProt | O14543          | SOCS3 [cytosol]
# UniProt | O75159          | SOCS5 [cytosol]
# UniProt | P48431          | SOX2 [nucleoplasm]
# UniProt | P42224          | STAT1 [cytosol]
# UniProt | P40763          | STAT3 [cytosol]
# UniProt | P42226          | STAT6 [cytosol]
# UniProt | P01137          | TGFB1(30-278) [extracellular region]
# UniProt | P01033          | TIMP1 [extracellular region]
# UniProt | P01375          | TNF(77-233) [extracellular region]
# UniProt | P20333          | TNFRSF1B [plasma membrane]
# UniProt | P04637          | TP53 [nucleoplasm]
# UniProt | Q15672          | TWIST1 [nucleoplasm]
# UniProt | P29597          | TYK2 [cytosol]
# UniProt | P19320          | VCAM1 [plasma membrane]
# UniProt | P15692          | VEGFA [extracellular region]
# UniProt | P08670          | VIM [cytosol]
# UniProt | P37275          | ZEB1 [nucleoplasm]
# UniProt | P00488          | factor XIII A chain [extracellular region]
# UniProt | P78552          | p-Y-IL13RA1 [plasma membrane]
# UniProt | P31785          | p-Y-IL2RG [plasma membrane]
# UniProt | P24394          | p-Y-IL4R [plasma membrane]
# UniProt | P23458          | p-Y-JAK1 [cytosol]
# UniProt | P29597          | p-Y-TYK2 [cytosol]
# UniProt | O60674          | p-Y1007-JAK2 [cytosol]
# UniProt | P42226          | p-Y641-STAT6 [cytosol]
# UniProt | P42226          | p-Y641-STAT6 [nucleoplasm]
# UniProt | P42224          | p-Y701-STAT1 [cytosol]
# UniProt | P42224          | p-Y701-STAT1 [nucleoplasm]
# UniProt | P40763          | p-Y705-STAT3 [cytosol]
# UniProt | P40763          | p-Y705-STAT3 [nucleoplasm]

# %% [markdown]
# Copyright (C) 2018-present, DV Klopfenstein. All rights reserved.
