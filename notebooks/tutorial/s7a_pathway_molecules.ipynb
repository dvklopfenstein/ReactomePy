# %% [markdown]
# # Tutorial 7a) Joining the pieces: Participating molecules for a pathway
# What are all the molecules in the pathway, R-HSA-983169, _Class I MHC mediated antigen processing & presentation_?
#
# [**Reactome Tutorial**: Joining the pieces: Participating molecules for a pathway](https://reactome.org/dev/graph-database/extract-participating-molecules#joining-pieces)
#
# ## Step 1) [Connect to Neo4j loaded with the Reactome Knowledgebase](https://github.com/dvklopfenstein/reactome_neo4j_py/blob/master/doc/md/README_gdbdr.md)

# %%
from neo4j import GraphDatabase

neo4j_url = 'bolt://localhost:7687'
neo4j_usr = 'neo4j'
neo4j_password = 'myneo4j_password'

gdbdr = GraphDatabase.driver(neo4j_url, auth=(neo4j_usr, neo4j_password))

# %% [markdown]
# ## Step 2) Pathway Molecules Query
# ### What are all the molecules in the pathway, R-HSA-983169, _Class I MHC mediated antigen processing & presentation_?

# %%
# Step 2) Pathway Molecules Query
# What are all the molecules in the pathway, R-HSA-983169, _Class I MHC mediated antigen processing & presentation_?

query = ('MATCH (p:Pathway{stId:"R-HSA-983169"})-[:hasEvent*]->(rle:ReactionLikeEvent),'
         '(rle)-[:'
         'input|output|catalystActivity|regulatedBy|'
         'physicalEntity|regulator|hasComponent|hasMember|hasCandidate*'
         ']->(pe:PhysicalEntity),'
         '(pe)-[:referenceEntity]->(re:ReferenceEntity)-[:referenceDatabase]->(rd:ReferenceDatabase)'
         'RETURN DISTINCT '
         'pe.displayName AS Name, re.identifier AS Identifier, rd.displayName AS Database')

# Query and get the sub-pathways under R-HSA-983169
def _get_data():
    with gdbdr.session() as session:
        return session.run(query).data()

data = _get_data()

# %% [markdown]
# ## Step 3) Print

# %%
# Print  all the molecules in the pathway, R-HSA-983169, Class I MHC mediated antigen processing & presentation
print('Database| ID     | Name')
print('--------|--------|------')
for data in sorted(data, key=lambda r:[r['Database'], r['Name']]):
    print("{Database:8}| {Identifier:6} | {Name}".format(**data))
# Out:
# Database| ID     | Name
# --------|--------|------
# ChEBI   | 59080  | (Glc)1 (GlcNAc)2 (Man)9 [ER to Golgi transport vesicle membrane]
# ChEBI   | 59080  | (Glc)1 (GlcNAc)2 (Man)9 [Golgi membrane]
# ChEBI   | 59080  | (Glc)1 (GlcNAc)2 (Man)9 [endoplasmic reticulum lumen]
# ChEBI   | 16761  | ADP [cytosol]
# ChEBI   | 16027  | AMP [cytosol]
# ChEBI   | 15422  | ATP [cytosol]
# ChEBI   | 25676  | Antigen peptide [early endosome lumen]
# ChEBI   | 25676  | Antigen peptide [endoplasmic reticulum lumen]
# ChEBI   | 8005   | Clostridial peptidoglycan [extracellular region]
# ChEBI   | 46896  | Diacyl lipopeptide [extracellular region]
# ChEBI   | 16670  | Exogenous soluble antigen [clathrin-coated endocytic vesicle membrane]
# ChEBI   | 16670  | Exogenous soluble antigen [cytosol]
# ChEBI   | 16670  | Exogenous soluble antigen [early endosome lumen]
# ChEBI   | 16670  | Exogenous soluble antigen [early endosome membrane]
# ChEBI   | 16670  | Exogenous soluble antigen [extracellular region]
# ChEBI   | 17552  | GDP [cytosol]
# ChEBI   | 15996  | GTP [ER to Golgi transport vesicle membrane]
# ChEBI   | 15996  | GTP [cytosol]
# ChEBI   | 15378  | H+ [phagolysosome]
# ChEBI   | 15377  | H2O [cytosol]
# ChEBI   | 59869  | L-amino acid [cytosol]
# ChEBI   | 59869  | L-amino acid [early endosome lumen]
# ChEBI   | 59869  | L-amino acid [endoplasmic reticulum lumen]
# ChEBI   | 16412  | LPS [extracellular region]
# ChEBI   | 28640  | Lipoteichoic acid [extracellular region]
# ChEBI   | 18420  | Mg2+ [cytosol]
# ChEBI   | 18009  | NADP+ [phagolysosome]
# ChEBI   | 16474  | NADPH [phagolysosome]
# ChEBI   | 15379  | O2 [phagolysosome]
# ChEBI   | 18421  | O2.- [phagolysosome]
# ChEBI   | 18348  | PI(4,5)P2 [plasma membrane]
# ChEBI   | 29888  | PPi [cytosol]
# ChEBI   | 18367  | Pi [cytosol]
# ChEBI   | 60192  | Triacyl lipopeptide [extracellular region]
# ChEBI   | 25676  | oligopeptide fragment (3-7aa) [cytosol]
# ChEBI   | 25676  | oligopeptide fragment (8-16aa) [cytosol]
# ChEBI   | 25676  | oligopeptide fragment [endoplasmic reticulum lumen]
# ChEBI   | 25676  | precursor peptide fragment (>16 aa) [cytosol]
# ChEBI   | 25676  | precursor peptide fragment (>16 aa) [early endosome lumen]
# UniProt | Q9Y6Y9 | 2xN4GlycoAsn-LY96 [plasma membrane]
# UniProt | O00206 | 2xN4GlycoAsn-TLR4 [plasma membrane]
# UniProt | P16671 | 4xPalmC-CD36 [plasma membrane]
# UniProt | Q9H1A4 | ANAPC1 [cytosol]
# UniProt | Q9UM13 | ANAPC10 [cytosol]
# UniProt | Q9NYG5 | ANAPC11 [cytosol]
# UniProt | Q9BS18 | ANAPC13 [cytosol]
# UniProt | Q9UJX6 | ANAPC2 [cytosol]
# UniProt | Q9UJX5 | ANAPC4 [cytosol]
# UniProt | Q9UJX4 | ANAPC5 [cytosol]
# UniProt | Q9UJX3 | ANAPC7 [cytosol]
# UniProt | O15033 | AREL1 [cytosol]
# UniProt | O95376 | ARIH2 [cytosol]
# UniProt | Q9Y576 | ASB1 [cytosol]
# UniProt | Q8WXI3 | ASB10 [cytosol]
# UniProt | Q8WXH4 | ASB11 [cytosol]
# UniProt | Q8WXK4 | ASB12 [cytosol]
# UniProt | Q8WXK3 | ASB13 [cytosol]
# UniProt | A6NK59 | ASB14 [cytosol]
# UniProt | Q8WXK1 | ASB15 [cytosol]
# UniProt | Q96NS5 | ASB16 [cytosol]
# UniProt | Q8WXJ9 | ASB17 [cytosol]
# UniProt | Q6ZVZ8 | ASB18 [cytosol]
# UniProt | Q96Q27 | ASB2 [cytosol]
# UniProt | Q9Y575 | ASB3 [cytosol]
# UniProt | Q9Y574 | ASB4 [cytosol]
# UniProt | Q8WWX0 | ASB5 [cytosol]
# UniProt | Q9NWX5 | ASB6 [cytosol]
# UniProt | Q9H672 | ASB7 [cytosol]
# UniProt | Q9H765 | ASB8 [cytosol]
# UniProt | Q96DX5 | ASB9 [cytosol]
# UniProt | O95352 | ATG7 [cytosol]
# UniProt | P61769 | B2M(21-119) [ER to Golgi transport vesicle membrane]
# UniProt | P61769 | B2M(21-119) [Golgi membrane]
# UniProt | P61769 | B2M(21-119) [early endosome lumen]
# UniProt | P61769 | B2M(21-119) [endoplasmic reticulum lumen]
# UniProt | P61769 | B2M(21-119) [phagocytic vesicle membrane]
# UniProt | P61769 | B2M(21-119) [plasma membrane]
# UniProt | P61769 | B2M(21-119) [recycling endosome membrane]
# UniProt | Q13867 | BLMH [cytosol]
# UniProt | Q9H0C5 | BTBD1 [cytosol]
# UniProt | Q96KE9 | BTBD6 [cytosol]
# UniProt | Q06187 | BTK [cytosol]
# UniProt | Q9Y297 | BTRC [cytosol]
# UniProt | P27797 | CALR [endoplasmic reticulum-Golgi intermediate compartment membrane]
# UniProt | P27797 | CALR [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P27797 | CALR [phagocytic vesicle membrane]
# UniProt | P27824 | CANX [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q13191 | CBLB [cytosol]
# UniProt | P41002 | CCNF [cytosol]
# UniProt | P08571 | CD14(20-345) [extracellular region]
# UniProt | Q9UJ71 | CD207 [clathrin-coated endocytic vesicle membrane]
# UniProt | Q9UJ71 | CD207 [early endosome membrane]
# UniProt | Q9UJ71 | CD207 [plasma membrane]
# UniProt | P16671 | CD36 [phagocytic vesicle]
# UniProt | Q13042 | CDC16 [cytosol]
# UniProt | Q12834 | CDC20 [cytosol]
# UniProt | Q9UJX2 | CDC23 [cytosol]
# UniProt | Q8NHZ8 | CDC26 [cytosol]
# UniProt | P30260 | CDC27 [cytosol]
# UniProt | P49427 | CDC34 [cytosol]
# UniProt | O15111 | CHUK [cytosol]
# UniProt | P07711 | CTSL1(114-288) [early endosome lumen]
# UniProt | O60911 | CTSL2 [early endosome lumen]
# UniProt | P25774 | CTSS [early endosome lumen]
# UniProt | Q13616 | CUL1 [cytosol]
# UniProt | Q13617 | CUL2 [cytosol]
# UniProt | Q13618 | CUL3 [cytosol]
# UniProt | Q93034 | CUL5 [cytosol]
# UniProt | Q14999 | CUL7 [cytosol]
# UniProt | P13498 | CYBA [phagocytic vesicle membrane]
# UniProt | P04839 | CYBB [phagocytic vesicle membrane]
# UniProt | Q7L5Y6 | DET1 [cytosol]
# UniProt | Q8TDB6 | DTX3L [cytosol]
# UniProt | Q86Y13 | DZIP3 [cytosol]
# UniProt | Q15370 | ELOB [cytosol]
# UniProt | Q15369 | ELOC [cytosol]
# UniProt | Q9NZ08 | ERAP1 [endoplasmic reticulum lumen]
# UniProt | Q6P179 | ERAP2 [endoplasmic reticulum lumen]
# UniProt | Q9NXK8 | FBXL12 [cytosol]
# UniProt | Q8NEE6 | FBXL13 [cytosol]
# UniProt | Q8N1E6 | FBXL14 [cytosol]
# UniProt | Q9H469 | FBXL15 [cytosol]
# UniProt | Q8N461 | FBXL16 [cytosol]
# UniProt | Q96ME1 | FBXL18 [cytosol]
# UniProt | Q6PCT2 | FBXL19 [cytosol]
# UniProt | Q96IG2 | FBXL20 [cytosol]
# UniProt | Q9UKT6 | FBXL21 [cytosol]
# UniProt | Q6P050 | FBXL22 [cytosol]
# UniProt | Q9UKT7 | FBXL3 [cytosol]
# UniProt | Q9UKA2 | FBXL4 [cytosol]
# UniProt | Q9UKA1 | FBXL5 [cytosol]
# UniProt | Q9UJT9 | FBXL7 [cytosol]
# UniProt | Q96CD0 | FBXL8 [cytosol]
# UniProt | Q9UK96 | FBXO10 [cytosol]
# UniProt | Q86XK2 | FBXO11 [cytosol]
# UniProt | Q8NCQ5 | FBXO15 [cytosol]
# UniProt | Q96EF6 | FBXO17 [cytosol]
# UniProt | Q9UK22 | FBXO2 [cytosol]
# UniProt | O94952 | FBXO21 [cytosol]
# UniProt | Q8NEZ5 | FBXO22 [cytosol]
# UniProt | Q8NI29 | FBXO27 [cytosol]
# UniProt | Q8TB52 | FBXO30 [cytosol]
# UniProt | Q5XUX0 | FBXO31 [cytosol]
# UniProt | Q969P5 | FBXO32 [cytosol]
# UniProt | Q9UKT5 | FBXO4 [cytosol]
# UniProt | Q9UH90 | FBXO40 [cytosol]
# UniProt | Q8TF61 | FBXO41 [cytosol]
# UniProt | Q9H4M3 | FBXO44 [cytosol]
# UniProt | Q9NRD1 | FBXO6 [cytosol]
# UniProt | Q9Y3I1 | FBXO7 [cytosol]
# UniProt | Q9UK97 | FBXO9 [cytosol]
# UniProt | Q5XX13 | FBXW10 [cytosol]
# UniProt | Q9UKB1 | FBXW11 [cytosol]
# UniProt | Q6X9E4 | FBXW12 [cytosol]
# UniProt | Q9UKT8 | FBXW2 [cytosol]
# UniProt | P57775 | FBXW4 [cytosol]
# UniProt | Q969U6 | FBXW5 [cytosol]
# UniProt | Q969H0 | FBXW7 [cytosol]
# UniProt | Q8N3Y1 | FBXW8 [cytosol]
# UniProt | Q5XUX1 | FBXW9 [cytosol]
# UniProt | P12314 | FCGR1A [clathrin-coated endocytic vesicle membrane]
# UniProt | P12314 | FCGR1A [early endosome membrane]
# UniProt | P12314 | FCGR1A [plasma membrane]
# UniProt | Q92637 | FCGR1B [clathrin-coated endocytic vesicle membrane]
# UniProt | Q92637 | FCGR1B [early endosome membrane]
# UniProt | Q92637 | FCGR1B [plasma membrane]
# UniProt | Q9UM11 | FZR1 [cytosol]
# UniProt | Q9H2C0 | GAN [cytosol]
# UniProt | Q92990 | GLMN [cytosol]
# UniProt | P08571 | GPIN-CD14(20-345) [plasma membrane]
# UniProt | Q8IYU2 | HACE1 [cytosol]
# UniProt | Q9ULT8 | HECTD1 [cytosol]
# UniProt | Q5U5R9 | HECTD2 [cytosol]
# UniProt | Q5T447 | HECTD3 [cytosol]
# UniProt | Q9P2P5 | HECW2 [cytosol]
# UniProt | Q15751 | HERC1 [cytosol]
# UniProt | O95714 | HERC2 [cytosol]
# UniProt | Q15034 | HERC3 [cytosol]
# UniProt | Q5GLZ8 | HERC4 [cytosol]
# UniProt | Q9UII4 | HERC5 [cytosol]
# UniProt | Q8IVU3 | HERC6 [cytosol]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [Golgi membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [early endosome membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [plasma membrane]
# UniProt | P30443 | HLA class I histocompatibility antigen, A-1 alpha chain precursor [recycling endosome membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [Golgi membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [early endosome membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [phagocytic vesicle membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [plasma membrane]
# UniProt | P13746 | HLA class I histocompatibility antigen, A-11 alpha chain [recycling endosome membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [Golgi membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [early endosome membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [phagocytic vesicle membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [plasma membrane]
# UniProt | P01892 | HLA class I histocompatibility antigen, A-2 alpha chain [recycling endosome membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [Golgi membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [early endosome membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [phagocytic vesicle membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [plasma membrane]
# UniProt | P30447 | HLA class I histocompatibility antigen, A-23 alpha chain [recycling endosome membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [Golgi membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [early endosome membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [phagocytic vesicle membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [plasma membrane]
# UniProt | P05534 | HLA class I histocompatibility antigen, A-24 alpha chain [recycling endosome membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [Golgi membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [early endosome membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [phagocytic vesicle membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [plasma membrane]
# UniProt | P18462 | HLA class I histocompatibility antigen, A-25 alpha chain [recycling endosome membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [Golgi membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [early endosome membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [phagocytic vesicle membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [plasma membrane]
# UniProt | P30450 | HLA class I histocompatibility antigen, A-26 alpha chain [recycling endosome membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [Golgi membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [early endosome membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [phagocytic vesicle membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [plasma membrane]
# UniProt | P30512 | HLA class I histocompatibility antigen, A-29 alpha chain [recycling endosome membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [Golgi membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [early endosome membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [plasma membrane]
# UniProt | P04439 | HLA class I histocompatibility antigen, A-3 alpha chain precursor [recycling endosome membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [Golgi membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [early endosome membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [phagocytic vesicle membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [plasma membrane]
# UniProt | P16188 | HLA class I histocompatibility antigen, A-30 alpha chain [recycling endosome membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [Golgi membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [early endosome membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [phagocytic vesicle membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [plasma membrane]
# UniProt | P16189 | HLA class I histocompatibility antigen, A-31 alpha chain [recycling endosome membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [Golgi membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [early endosome membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [phagocytic vesicle membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [plasma membrane]
# UniProt | P10314 | HLA class I histocompatibility antigen, A-32 alpha chain [recycling endosome membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [Golgi membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [early endosome membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [phagocytic vesicle membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [plasma membrane]
# UniProt | P16190 | HLA class I histocompatibility antigen, A-33 alpha chain [recycling endosome membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [Golgi membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [early endosome membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [phagocytic vesicle membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [plasma membrane]
# UniProt | P30453 | HLA class I histocompatibility antigen, A-34 alpha chain [recycling endosome membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [Golgi membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [early endosome membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [phagocytic vesicle membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [plasma membrane]
# UniProt | P30455 | HLA class I histocompatibility antigen, A-36 alpha chain [recycling endosome membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [Golgi membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [early endosome membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [phagocytic vesicle membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [plasma membrane]
# UniProt | P30456 | HLA class I histocompatibility antigen, A-43 alpha chain [recycling endosome membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [Golgi membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [early endosome membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [phagocytic vesicle membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [plasma membrane]
# UniProt | P30457 | HLA class I histocompatibility antigen, A-66 alpha chain [recycling endosome membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [Golgi membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [early endosome membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [phagocytic vesicle membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [plasma membrane]
# UniProt | P01891 | HLA class I histocompatibility antigen, A-68 alpha chain [recycling endosome membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [Golgi membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [early endosome membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [phagocytic vesicle membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [plasma membrane]
# UniProt | P10316 | HLA class I histocompatibility antigen, A-69 alpha chain [recycling endosome membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [Golgi membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [early endosome membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [phagocytic vesicle membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [plasma membrane]
# UniProt | P30459 | HLA class I histocompatibility antigen, A-74 alpha chain [recycling endosome membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [Golgi membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [early endosome membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [phagocytic vesicle membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [plasma membrane]
# UniProt | Q09160 | HLA class I histocompatibility antigen, A-80 alpha chain [recycling endosome membrane]
# UniProt | P30486 | HLA class I histocompatibility antigen, B-48 alpha chain [plasma membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [Golgi membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [early endosome membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [phagocytic vesicle membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [plasma membrane]
# UniProt | P30499 | HLA class I histocompatibility antigen, Cw-1 alpha chain [recycling endosome membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [Golgi membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [early endosome membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [phagocytic vesicle membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [plasma membrane]
# UniProt | P30508 | HLA class I histocompatibility antigen, Cw-12 alpha chain [recycling endosome membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [Golgi membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [early endosome membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [phagocytic vesicle membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [plasma membrane]
# UniProt | P30510 | HLA class I histocompatibility antigen, Cw-14 alpha chain [recycling endosome membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [Golgi membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [early endosome membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [phagocytic vesicle membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [plasma membrane]
# UniProt | Q07000 | HLA class I histocompatibility antigen, Cw-15 alpha chain [recycling endosome membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [Golgi membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [early endosome membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [phagocytic vesicle membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [plasma membrane]
# UniProt | Q29960 | HLA class I histocompatibility antigen, Cw-16 alpha chain [recycling endosome membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [Golgi membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [early endosome membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [phagocytic vesicle membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [plasma membrane]
# UniProt | Q95604 | HLA class I histocompatibility antigen, Cw-17 alpha chain [recycling endosome membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [Golgi membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [early endosome membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [phagocytic vesicle membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [plasma membrane]
# UniProt | Q29865 | HLA class I histocompatibility antigen, Cw-18 alpha chain [recycling endosome membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [Golgi membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [early endosome membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [phagocytic vesicle membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [plasma membrane]
# UniProt | P30501 | HLA class I histocompatibility antigen, Cw-2 alpha chain [recycling endosome membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [Golgi membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [early endosome membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [plasma membrane]
# UniProt | P04222 | HLA class I histocompatibility antigen, Cw-3 alpha chain precursor [recycling endosome membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [Golgi membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [early endosome membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [plasma membrane]
# UniProt | P30504 | HLA class I histocompatibility antigen, Cw-4 alpha chain precursor [recycling endosome membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [Golgi membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [early endosome membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [plasma membrane]
# UniProt | Q9TNN7 | HLA class I histocompatibility antigen, Cw-5 alpha chain precursor [recycling endosome membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [Golgi membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [early endosome membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [plasma membrane]
# UniProt | Q29963 | HLA class I histocompatibility antigen, Cw-6 alpha chain precursor [recycling endosome membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [Golgi membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [early endosome membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P10321 | HLA class I histocompatibility antigen, Cw-7 alpha chain precursor [recycling endosome membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [ER to Golgi transport vesicle membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [Golgi membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [early endosome membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [phagocytic vesicle membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [plasma membrane]
# UniProt | P30505 | HLA class I histocompatibility antigen, Cw-8 alpha chain [recycling endosome membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [ER to Golgi transport vesicle membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [Golgi membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [early endosome membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [phagocytic vesicle membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [plasma membrane]
# UniProt | P13747 | HLA class I histocompatibility antigen, E alpha chain precursor [recycling endosome membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [ER to Golgi transport vesicle membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [Golgi membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [early endosome membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [phagocytic vesicle membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [plasma membrane]
# UniProt | P30511 | HLA class I histocompatibility antigen, alpha chain F precursor [recycling endosome membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [ER to Golgi transport vesicle membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [Golgi membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [early endosome membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [phagocytic vesicle membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [plasma membrane]
# UniProt | P17693 | HLA class I histocompatibility antigen, alpha chain G precursor [recycling endosome membrane]
# UniProt | P30486 | HLA-B [ER to Golgi transport vesicle membrane]
# UniProt | P30486 | HLA-B [Golgi membrane]
# UniProt | P30486 | HLA-B [early endosome membrane]
# UniProt | P30486 | HLA-B [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30486 | HLA-B [phagocytic vesicle membrane]
# UniProt | P30486 | HLA-B [recycling endosome membrane]
# UniProt | P10321 | HLA-C [plasma membrane]
# UniProt | P01893 | HLA-H [ER to Golgi transport vesicle membrane]
# UniProt | P01893 | HLA-H [Golgi membrane]
# UniProt | P01893 | HLA-H [early endosome membrane]
# UniProt | P01893 | HLA-H [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P01893 | HLA-H [phagocytic vesicle membrane]
# UniProt | P01893 | HLA-H [plasma membrane]
# UniProt | P01893 | HLA-H [recycling endosome membrane]
# UniProt | P11021 | HSPA5 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q7Z6Z7 | HUWE1 [cytosol]
# UniProt | O14920 | IKBKB [cytosol]
# UniProt | Q9Y6K9 | IKBKG [cytosol]
# UniProt | Q96J02 | ITCH [cytosol]
# UniProt | P06756 | ITGAV(31-1048) [phagocytic vesicle]
# UniProt | P06756 | ITGAV(31-1048) [plasma membrane]
# UniProt | P18084 | ITGB5 [phagocytic vesicle]
# UniProt | P18084 | ITGB5 [plasma membrane]
# UniProt | C9JR72 | KBTBD13 [cytosol]
# UniProt | Q86V97 | KBTBD6 [cytosol]
# UniProt | Q8WVZ9 | KBTBD7 [cytosol]
# UniProt | Q8NFY9 | KBTBD8 [cytosol]
# UniProt | Q8NC69 | KCTD6 [cytosol]
# UniProt | Q96MP8 | KCTD7 [cytosol]
# UniProt | Q14145 | KEAP1 [cytosol]
# UniProt | Q9NVR0 | KLHL11 [cytosol]
# UniProt | Q9P2N7 | KLHL13 [cytosol]
# UniProt | O95198 | KLHL2 [cytosol]
# UniProt | Q9Y2M5 | KLHL20 [cytosol]
# UniProt | Q9UJP4 | KLHL21 [cytosol]
# UniProt | Q53GT1 | KLHL22 [cytosol]
# UniProt | Q9H0H3 | KLHL25 [cytosol]
# UniProt | Q9UH77 | KLHL3 [cytosol]
# UniProt | O60662 | KLHL41 [cytosol]
# UniProt | Q9P2K6 | KLHL42 [cytosol]
# UniProt | Q96PQ7 | KLHL5 [cytosol]
# UniProt | Q9P2J3 | KLHL9 [cytosol]
# UniProt | Q8WWI1 | LMO7 [cytosol]
# UniProt | Q9UIQ6 | LNPEP [cytosol]
# UniProt | Q9UIQ6 | LNPEP [early endosome lumen]
# UniProt | Q8TBB1 | LNX1 [cytosol]
# UniProt | Q17RB8 | LONRF1 [cytosol]
# UniProt | Q96L50 | LRR1 [cytosol]
# UniProt | Q15345 | LRRC41 [cytosol]
# UniProt | Q6UWE0 | LRSAM1 [cytosol]
# UniProt | O94822 | LTN1 [cytosol]
# UniProt | Q5U5Q3 | MEX3C [cytosol]
# UniProt | O60291 | MGRN1 [cytosol]
# UniProt | Q96AX9 | MIB2 [cytosol]
# UniProt | Q9UHC7 | MKRN1 [cytosol]
# UniProt | P22897 | MRC1 [clathrin-coated endocytic vesicle membrane]
# UniProt | P22897 | MRC1 [early endosome membrane]
# UniProt | P22897 | MRC1 [plasma membrane]
# UniProt | Q9UBG0 | MRC2 [clathrin-coated endocytic vesicle membrane]
# UniProt | Q9UBG0 | MRC2 [early endosome membrane]
# UniProt | Q9UBG0 | MRC2 [plasma membrane]
# UniProt | Q99836 | MYD88 [plasma membrane]
# UniProt | Q8WY64 | MYLIP [cytosol]
# UniProt | P30690 | Major outer membrane protein P [extracellular region]
# UniProt | P46934 | NEDD4 [cytosol]
# UniProt | Q96PU5 | NEDD4L [cytosol]
# UniProt | P55786 | NPEPPS [cytosol]
# UniProt | O60260 | PARK2 [cytosol]
# UniProt | P30101 | PDIA3 [endoplasmic reticulum lumen]
# UniProt | P30101 | PDIA3 [phagocytic vesicle]
# UniProt | P30101 | PDIA3 [recycling endosome membrane]
# UniProt | Q8NG27 | PJA1 [cytosol]
# UniProt | O43164 | PJA2 [cytosol]
# UniProt | P25786 | PSMA1 [cytosol]
# UniProt | P25787 | PSMA2 [cytosol]
# UniProt | P25788 | PSMA3 [cytosol]
# UniProt | P25789 | PSMA4 [cytosol]
# UniProt | P28066 | PSMA5 [cytosol]
# UniProt | P60900 | PSMA6 [cytosol]
# UniProt | O14818 | PSMA7 [cytosol]
# UniProt | Q8TAA3 | PSMA8 [cytosol]
# UniProt | P20618 | PSMB1 [cytosol]
# UniProt | P40306 | PSMB10 [cytosol]
# UniProt | A5LHX3 | PSMB11 [cytosol]
# UniProt | P49721 | PSMB2 [cytosol]
# UniProt | P49720 | PSMB3 [cytosol]
# UniProt | P28070 | PSMB4 [cytosol]
# UniProt | P28074 | PSMB5 [cytosol]
# UniProt | P28072 | PSMB6 [cytosol]
# UniProt | Q99436 | PSMB7 [cytosol]
# UniProt | P28062 | PSMB8 [cytosol]
# UniProt | P28065 | PSMB9 [cytosol]
# UniProt | P62191 | PSMC1 [cytosol]
# UniProt | P35998 | PSMC2 [cytosol]
# UniProt | P17980 | PSMC3 [cytosol]
# UniProt | P43686 | PSMC4 [cytosol]
# UniProt | P62195 | PSMC5 [cytosol]
# UniProt | P62333 | PSMC6 [cytosol]
# UniProt | Q99460 | PSMD1 [cytosol]
# UniProt | O75832 | PSMD10 [cytosol]
# UniProt | O00231 | PSMD11 [cytosol]
# UniProt | O00232 | PSMD12 [cytosol]
# UniProt | Q9UNM6 | PSMD13 [cytosol]
# UniProt | O00487 | PSMD14 [cytosol]
# UniProt | Q13200 | PSMD2 [cytosol]
# UniProt | O43242 | PSMD3 [cytosol]
# UniProt | P55036 | PSMD4 [cytosol]
# UniProt | Q16401 | PSMD5 [cytosol]
# UniProt | Q15008 | PSMD6 [cytosol]
# UniProt | P51665 | PSMD7 [cytosol]
# UniProt | P48556 | PSMD8 [cytosol]
# UniProt | O00233 | PSMD9 [cytosol]
# UniProt | Q06323 | PSME1 [cytosol]
# UniProt | Q9UL46 | PSME2 [cytosol]
# UniProt | P61289 | PSME3 [cytosol]
# UniProt | Q14997 | PSME4 [cytosol]
# UniProt | Q92530 | PSMF1 [cytosol]
# UniProt | Q7Z6E9 | RBBP6 [cytosol]
# UniProt | Q9BYM8 | RBCK1 [cytosol]
# UniProt | P62877 | RBX1 [cytosol]
# UniProt | Q96PM5 | RCHY1 [cytosol]
# UniProt | Q9NVW2 | RLIM [cytosol]
# UniProt | Q6ZNA4 | RNF111 [cytosol]
# UniProt | Q9Y508 | RNF114 [cytosol]
# UniProt | Q9Y4L5 | RNF115 [cytosol]
# UniProt | Q5XPI4 | RNF123 [cytosol]
# UniProt | Q9BV68 | RNF126 [cytosol]
# UniProt | Q86XS8 | RNF130 [cytosol]
# UniProt | Q8WVD3 | RNF138 [cytosol]
# UniProt | Q9UBS8 | RNF14 [cytosol]
# UniProt | Q7Z419 | RNF144B [cytosol]
# UniProt | Q8N6D2 | RNF182 [cytosol]
# UniProt | Q9NV58 | RNF19A [cytosol]
# UniProt | Q6ZMZ0 | RNF19B [cytosol]
# UniProt | Q63HN8 | RNF213 [cytosol]
# UniProt | Q8TC41 | RNF217 [cytosol]
# UniProt | Q5VTB9 | RNF220 [cytosol]
# UniProt | Q96BH1 | RNF25 [cytosol]
# UniProt | Q969K3 | RNF34 [cytosol]
# UniProt | P78317 | RNF4 [cytosol]
# UniProt | Q9H4P4 | RNF41 [cytosol]
# UniProt | Q9Y252 | RNF6 [cytosol]
# UniProt | Q9UBF6 | RNF7 (RBX2) [cytosol]
# UniProt | P62979 | RPS27A(1-76) [cytosol]
# UniProt | Q9Y6B6 | SAR1B [ER to Golgi transport vesicle membrane]
# UniProt | Q9Y6B6 | SAR1B [cytosol]
# UniProt | Q9Y6B6 | SAR1B [endoplasmic reticulum membrane]
# UniProt | P55735 | SEC13 [ER to Golgi transport vesicle membrane]
# UniProt | P55735 | SEC13 [cytosol]
# UniProt | P55735 | SEC13 [endoplasmic reticulum membrane]
# UniProt | O75396 | SEC22B [endoplasmic reticulum membrane]
# UniProt | O75396 | SEC22B [endoplasmic reticulum-Golgi intermediate compartment membrane]
# UniProt | O75396 | SEC22B [phagocytic vesicle membrane]
# UniProt | Q15436 | SEC23A [ER to Golgi transport vesicle membrane]
# UniProt | Q15436 | SEC23A [cytosol]
# UniProt | Q15436 | SEC23A [endoplasmic reticulum membrane]
# UniProt | O95486 | SEC24A [ER to Golgi transport vesicle membrane]
# UniProt | O95486 | SEC24A [cytosol]
# UniProt | O95486 | SEC24A [endoplasmic reticulum membrane]
# UniProt | O95487 | SEC24B [ER to Golgi transport vesicle membrane]
# UniProt | O95487 | SEC24B [cytosol]
# UniProt | O95487 | SEC24B [endoplasmic reticulum membrane]
# UniProt | P53992 | SEC24C [ER to Golgi transport vesicle membrane]
# UniProt | P53992 | SEC24C [cytosol]
# UniProt | P53992 | SEC24C [endoplasmic reticulum membrane]
# UniProt | O94855 | SEC24D [ER to Golgi transport vesicle membrane]
# UniProt | O94855 | SEC24D [cytosol]
# UniProt | O94855 | SEC24D [endoplasmic reticulum membrane]
# UniProt | O94979 | SEC31A [ER to Golgi transport vesicle membrane]
# UniProt | O94979 | SEC31A [cytosol]
# UniProt | O94979 | SEC31A [endoplasmic reticulum membrane]
# UniProt | P61619 | SEC61A1 [phagocytic vesicle membrane]
# UniProt | Q9H9S3 | SEC61A2 [phagocytic vesicle membrane]
# UniProt | P60468 | SEC61B [phagocytic vesicle membrane]
# UniProt | P60059 | SEC61G [phagocytic vesicle membrane]
# UniProt | Q7Z6J0 | SH3RF1 [cytosol]
# UniProt | P60896 | SHFM1 [cytosol]
# UniProt | Q8IUQ4 | SIAH1 [cytosol]
# UniProt | O43255 | SIAH2 [cytosol]
# UniProt | P63208 | SKP1 [cytosol]
# UniProt | Q13309 | SKP2 [cytosol]
# UniProt | Q9HCE7 | SMURF1 [cytosol]
# UniProt | Q9HAU4 | SMURF2 [cytosol]
# UniProt | O00161 | SNAP23 [phagocytic vesicle membrane]
# UniProt | O15524 | SOCS1 [cytosol]
# UniProt | O14543 | SOCS3 [cytosol]
# UniProt | Q96BD6 | SPSB1 [cytosol]
# UniProt | Q99619 | SPSB2 [cytosol]
# UniProt | Q96A44 | SPSB4 [cytosol]
# UniProt | Q9UNE7 | STUB1 [cytosol]
# UniProt | Q12846 | STX4 [phagocytic vesicle membrane]
# UniProt | Q03518 | TAP1 [endoplasmic reticulum membrane]
# UniProt | Q03518 | TAP1 [endoplasmic reticulum-Golgi intermediate compartment membrane]
# UniProt | Q03518 | TAP1 [phagocytic vesicle membrane]
# UniProt | Q03519 | TAP2 [endoplasmic reticulum membrane]
# UniProt | Q03519 | TAP2 [endoplasmic reticulum-Golgi intermediate compartment membrane]
# UniProt | Q03519 | TAP2 [phagocytic vesicle membrane]
# UniProt | O15533 | TAPBP [endoplasmic reticulum-Golgi intermediate compartment membrane]
# UniProt | O15533 | TAPBP [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | O15533 | TAPBP [phagocytic vesicle membrane]
# UniProt | P52888 | THOP1 [cytosol]
# UniProt | Q15399 | TLR1 [plasma membrane]
# UniProt | O60603 | TLR2 [plasma membrane]
# UniProt | Q9Y2C9 | TLR6 [plasma membrane]
# UniProt | P29144 | TPP2 [cytosol]
# UniProt | Q6Q0C0 | TRAF7 [cytosol]
# UniProt | Q9BWF2 | TRAIP [cytosol]
# UniProt | Q96F44 | TRIM11 [cytosol]
# UniProt | P19474 | TRIM21 [cytosol]
# UniProt | Q13049 | TRIM32 [cytosol]
# UniProt | Q9NQ86 | TRIM36 [cytosol]
# UniProt | O94972 | TRIM37 [cytosol]
# UniProt | Q9HCM9 | TRIM39 [cytosol]
# UniProt | Q9C037 | TRIM4 [cytosol]
# UniProt | Q8WV44 | TRIM41 [cytosol]
# UniProt | Q86XT4 | TRIM50 [cytosol]
# UniProt | Q969Q1 | TRIM63 [cytosol]
# UniProt | Q86WT6 | TRIM69 [cytosol]
# UniProt | Q2Q1W2 | TRIM71 [cytosol]
# UniProt | Q9C026 | TRIM9 [cytosol]
# UniProt | Q14669 | TRIP12 [cytosol]
# UniProt | P22314 | UBA1 [cytosol]
# UniProt | Q8TBC4 | UBA3 [cytosol]
# UniProt | Q9GZZ9 | UBA5 [cytosol]
# UniProt | P62987 | UBA52(1-76) [cytosol]
# UniProt | A0AVT1 | UBA6 [cytosol]
# UniProt | P41226 | UBA7 [cytosol]
# UniProt | Q9BSL1 | UBAC1 [cytosol]
# UniProt | P0CG47 | UBB(1-76) [cytosol]
# UniProt | P0CG47 | UBB(153-228) [cytosol]
# UniProt | P0CG47 | UBB(77-152) [cytosol]
# UniProt | P0CG48 | UBC(1-76) [cytosol]
# UniProt | P0CG48 | UBC(153-228) [cytosol]
# UniProt | P0CG48 | UBC(229-304) [cytosol]
# UniProt | P0CG48 | UBC(305-380) [cytosol]
# UniProt | P0CG48 | UBC(381-456) [cytosol]
# UniProt | P0CG48 | UBC(457-532) [cytosol]
# UniProt | P0CG48 | UBC(533-608) [cytosol]
# UniProt | P0CG48 | UBC(609-684) [cytosol]
# UniProt | P0CG48 | UBC(77-152) [cytosol]
# UniProt | P49459 | UBE2A [cytosol]
# UniProt | P63146 | UBE2B [cytosol]
# UniProt | O00762 | UBE2C [cytosol]
# UniProt | P51668 | UBE2D1 [cytosol]
# UniProt | P62837 | UBE2D2 [cytosol]
# ...
# UniProt | P30462 | class I MHC B14 [Golgi membrane]
# UniProt | P30462 | class I MHC B14 [early endosome membrane]
# UniProt | P30462 | class I MHC B14 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30462 | class I MHC B14 [phagocytic vesicle membrane]
# UniProt | P30462 | class I MHC B14 [plasma membrane]
# UniProt | P30462 | class I MHC B14 [recycling endosome membrane]
# UniProt | P30464 | class I MHC B15 [ER to Golgi transport vesicle membrane]
# UniProt | P30464 | class I MHC B15 [Golgi membrane]
# UniProt | P30464 | class I MHC B15 [early endosome membrane]
# UniProt | P30464 | class I MHC B15 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30464 | class I MHC B15 [phagocytic vesicle membrane]
# UniProt | P30464 | class I MHC B15 [plasma membrane]
# UniProt | P30464 | class I MHC B15 [recycling endosome membrane]
# UniProt | P30466 | class I MHC B18 [ER to Golgi transport vesicle membrane]
# UniProt | P30466 | class I MHC B18 [Golgi membrane]
# UniProt | P30466 | class I MHC B18 [early endosome membrane]
# UniProt | P30466 | class I MHC B18 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30466 | class I MHC B18 [phagocytic vesicle membrane]
# UniProt | P30466 | class I MHC B18 [plasma membrane]
# UniProt | P30466 | class I MHC B18 [recycling endosome membrane]
# UniProt | P03989 | class I MHC B27 [ER to Golgi transport vesicle membrane]
# UniProt | P03989 | class I MHC B27 [Golgi membrane]
# UniProt | P03989 | class I MHC B27 [early endosome membrane]
# UniProt | P03989 | class I MHC B27 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P03989 | class I MHC B27 [phagocytic vesicle membrane]
# UniProt | P03989 | class I MHC B27 [plasma membrane]
# UniProt | P03989 | class I MHC B27 [recycling endosome membrane]
# UniProt | P30685 | class I MHC B35 [ER to Golgi transport vesicle membrane]
# UniProt | P30685 | class I MHC B35 [Golgi membrane]
# UniProt | P30685 | class I MHC B35 [early endosome membrane]
# UniProt | P30685 | class I MHC B35 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30685 | class I MHC B35 [phagocytic vesicle membrane]
# UniProt | P30685 | class I MHC B35 [plasma membrane]
# UniProt | P30685 | class I MHC B35 [recycling endosome membrane]
# UniProt | P18463 | class I MHC B37 [ER to Golgi transport vesicle membrane]
# UniProt | P18463 | class I MHC B37 [Golgi membrane]
# UniProt | P18463 | class I MHC B37 [early endosome membrane]
# UniProt | P18463 | class I MHC B37 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P18463 | class I MHC B37 [phagocytic vesicle membrane]
# UniProt | P18463 | class I MHC B37 [plasma membrane]
# UniProt | P18463 | class I MHC B37 [recycling endosome membrane]
# UniProt | Q95365 | class I MHC B38 [ER to Golgi transport vesicle membrane]
# UniProt | Q95365 | class I MHC B38 [Golgi membrane]
# UniProt | Q95365 | class I MHC B38 [early endosome membrane]
# UniProt | Q95365 | class I MHC B38 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q95365 | class I MHC B38 [phagocytic vesicle membrane]
# UniProt | Q95365 | class I MHC B38 [plasma membrane]
# UniProt | Q95365 | class I MHC B38 [recycling endosome membrane]
# UniProt | P30475 | class I MHC B39 [ER to Golgi transport vesicle membrane]
# UniProt | P30475 | class I MHC B39 [Golgi membrane]
# UniProt | P30475 | class I MHC B39 [early endosome membrane]
# UniProt | P30475 | class I MHC B39 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30475 | class I MHC B39 [phagocytic vesicle membrane]
# UniProt | P30475 | class I MHC B39 [plasma membrane]
# UniProt | P30475 | class I MHC B39 [recycling endosome membrane]
# UniProt | Q04826 | class I MHC B40 [ER to Golgi transport vesicle membrane]
# UniProt | Q04826 | class I MHC B40 [Golgi membrane]
# UniProt | Q04826 | class I MHC B40 [early endosome membrane]
# UniProt | Q04826 | class I MHC B40 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q04826 | class I MHC B40 [phagocytic vesicle membrane]
# UniProt | Q04826 | class I MHC B40 [plasma membrane]
# UniProt | Q04826 | class I MHC B40 [recycling endosome membrane]
# UniProt | P30479 | class I MHC B41 [ER to Golgi transport vesicle membrane]
# UniProt | P30479 | class I MHC B41 [Golgi membrane]
# UniProt | P30479 | class I MHC B41 [early endosome membrane]
# UniProt | P30479 | class I MHC B41 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30479 | class I MHC B41 [phagocytic vesicle membrane]
# UniProt | P30479 | class I MHC B41 [plasma membrane]
# UniProt | P30479 | class I MHC B41 [recycling endosome membrane]
# UniProt | P30480 | class I MHC B42 [ER to Golgi transport vesicle membrane]
# UniProt | P30480 | class I MHC B42 [Golgi membrane]
# UniProt | P30480 | class I MHC B42 [early endosome membrane]
# UniProt | P30480 | class I MHC B42 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30480 | class I MHC B42 [phagocytic vesicle membrane]
# UniProt | P30480 | class I MHC B42 [plasma membrane]
# UniProt | P30480 | class I MHC B42 [recycling endosome membrane]
# UniProt | P30481 | class I MHC B44 [ER to Golgi transport vesicle membrane]
# UniProt | P30481 | class I MHC B44 [Golgi membrane]
# UniProt | P30481 | class I MHC B44 [early endosome membrane]
# UniProt | P30481 | class I MHC B44 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30481 | class I MHC B44 [phagocytic vesicle membrane]
# UniProt | P30481 | class I MHC B44 [plasma membrane]
# UniProt | P30481 | class I MHC B44 [recycling endosome membrane]
# UniProt | P30483 | class I MHC B45 [ER to Golgi transport vesicle membrane]
# UniProt | P30483 | class I MHC B45 [Golgi membrane]
# UniProt | P30483 | class I MHC B45 [early endosome membrane]
# UniProt | P30483 | class I MHC B45 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30483 | class I MHC B45 [phagocytic vesicle membrane]
# UniProt | P30483 | class I MHC B45 [plasma membrane]
# UniProt | P30483 | class I MHC B45 [recycling endosome membrane]
# UniProt | P30484 | class I MHC B46 [ER to Golgi transport vesicle membrane]
# UniProt | P30484 | class I MHC B46 [Golgi membrane]
# UniProt | P30484 | class I MHC B46 [early endosome membrane]
# UniProt | P30484 | class I MHC B46 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30484 | class I MHC B46 [phagocytic vesicle membrane]
# UniProt | P30484 | class I MHC B46 [plasma membrane]
# UniProt | P30484 | class I MHC B46 [recycling endosome membrane]
# UniProt | P30485 | class I MHC B47 [ER to Golgi transport vesicle membrane]
# UniProt | P30485 | class I MHC B47 [Golgi membrane]
# UniProt | P30485 | class I MHC B47 [early endosome membrane]
# UniProt | P30485 | class I MHC B47 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30485 | class I MHC B47 [phagocytic vesicle membrane]
# UniProt | P30485 | class I MHC B47 [plasma membrane]
# UniProt | P30485 | class I MHC B47 [recycling endosome membrane]
# UniProt | P30487 | class I MHC B49 [ER to Golgi transport vesicle membrane]
# UniProt | P30487 | class I MHC B49 [Golgi membrane]
# UniProt | P30487 | class I MHC B49 [early endosome membrane]
# UniProt | P30487 | class I MHC B49 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30487 | class I MHC B49 [phagocytic vesicle membrane]
# UniProt | P30487 | class I MHC B49 [plasma membrane]
# UniProt | P30487 | class I MHC B49 [recycling endosome membrane]
# UniProt | P30488 | class I MHC B50 [ER to Golgi transport vesicle membrane]
# UniProt | P30488 | class I MHC B50 [Golgi membrane]
# UniProt | P30488 | class I MHC B50 [early endosome membrane]
# UniProt | P30488 | class I MHC B50 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30488 | class I MHC B50 [phagocytic vesicle membrane]
# UniProt | P30488 | class I MHC B50 [plasma membrane]
# UniProt | P30488 | class I MHC B50 [recycling endosome membrane]
# UniProt | P18464 | class I MHC B51 [ER to Golgi transport vesicle membrane]
# UniProt | P18464 | class I MHC B51 [Golgi membrane]
# UniProt | P18464 | class I MHC B51 [early endosome membrane]
# UniProt | P18464 | class I MHC B51 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P18464 | class I MHC B51 [phagocytic vesicle membrane]
# UniProt | P18464 | class I MHC B51 [plasma membrane]
# UniProt | P18464 | class I MHC B51 [recycling endosome membrane]
# UniProt | P30490 | class I MHC B52 [ER to Golgi transport vesicle membrane]
# UniProt | P30490 | class I MHC B52 [Golgi membrane]
# UniProt | P30490 | class I MHC B52 [early endosome membrane]
# UniProt | P30490 | class I MHC B52 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30490 | class I MHC B52 [phagocytic vesicle membrane]
# UniProt | P30490 | class I MHC B52 [plasma membrane]
# UniProt | P30490 | class I MHC B52 [recycling endosome membrane]
# UniProt | P30491 | class I MHC B53 [ER to Golgi transport vesicle membrane]
# UniProt | P30491 | class I MHC B53 [Golgi membrane]
# UniProt | P30491 | class I MHC B53 [early endosome membrane]
# UniProt | P30491 | class I MHC B53 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30491 | class I MHC B53 [phagocytic vesicle membrane]
# UniProt | P30491 | class I MHC B53 [plasma membrane]
# UniProt | P30491 | class I MHC B53 [recycling endosome membrane]
# UniProt | P30492 | class I MHC B54 [ER to Golgi transport vesicle membrane]
# UniProt | P30492 | class I MHC B54 [Golgi membrane]
# UniProt | P30492 | class I MHC B54 [early endosome membrane]
# UniProt | P30492 | class I MHC B54 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30492 | class I MHC B54 [phagocytic vesicle membrane]
# UniProt | P30492 | class I MHC B54 [plasma membrane]
# UniProt | P30492 | class I MHC B54 [recycling endosome membrane]
# UniProt | P30493 | class I MHC B55 [ER to Golgi transport vesicle membrane]
# UniProt | P30493 | class I MHC B55 [Golgi membrane]
# UniProt | P30493 | class I MHC B55 [early endosome membrane]
# UniProt | P30493 | class I MHC B55 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30493 | class I MHC B55 [phagocytic vesicle membrane]
# UniProt | P30493 | class I MHC B55 [plasma membrane]
# UniProt | P30493 | class I MHC B55 [recycling endosome membrane]
# UniProt | P30495 | class I MHC B56 [ER to Golgi transport vesicle membrane]
# UniProt | P30495 | class I MHC B56 [Golgi membrane]
# UniProt | P30495 | class I MHC B56 [early endosome membrane]
# UniProt | P30495 | class I MHC B56 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30495 | class I MHC B56 [phagocytic vesicle membrane]
# UniProt | P30495 | class I MHC B56 [plasma membrane]
# UniProt | P30495 | class I MHC B56 [recycling endosome membrane]
# UniProt | P18465 | class I MHC B57 [ER to Golgi transport vesicle membrane]
# UniProt | P18465 | class I MHC B57 [Golgi membrane]
# UniProt | P18465 | class I MHC B57 [early endosome membrane]
# UniProt | P18465 | class I MHC B57 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P18465 | class I MHC B57 [phagocytic vesicle membrane]
# UniProt | P18465 | class I MHC B57 [plasma membrane]
# UniProt | P18465 | class I MHC B57 [recycling endosome membrane]
# UniProt | P10319 | class I MHC B58 [ER to Golgi transport vesicle membrane]
# UniProt | P10319 | class I MHC B58 [Golgi membrane]
# UniProt | P10319 | class I MHC B58 [early endosome membrane]
# UniProt | P10319 | class I MHC B58 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P10319 | class I MHC B58 [phagocytic vesicle membrane]
# UniProt | P10319 | class I MHC B58 [plasma membrane]
# UniProt | P10319 | class I MHC B58 [recycling endosome membrane]
# UniProt | Q29940 | class I MHC B59 [ER to Golgi transport vesicle membrane]
# UniProt | Q29940 | class I MHC B59 [Golgi membrane]
# UniProt | Q29940 | class I MHC B59 [early endosome membrane]
# UniProt | Q29940 | class I MHC B59 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29940 | class I MHC B59 [phagocytic vesicle membrane]
# UniProt | Q29940 | class I MHC B59 [plasma membrane]
# UniProt | Q29940 | class I MHC B59 [recycling endosome membrane]
# UniProt | Q29836 | class I MHC B67 [ER to Golgi transport vesicle membrane]
# UniProt | Q29836 | class I MHC B67 [Golgi membrane]
# UniProt | Q29836 | class I MHC B67 [early endosome membrane]
# UniProt | Q29836 | class I MHC B67 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29836 | class I MHC B67 [phagocytic vesicle membrane]
# UniProt | Q29836 | class I MHC B67 [plasma membrane]
# UniProt | Q29836 | class I MHC B67 [recycling endosome membrane]
# UniProt | P01889 | class I MHC B7 [ER to Golgi transport vesicle membrane]
# UniProt | P01889 | class I MHC B7 [Golgi membrane]
# UniProt | P01889 | class I MHC B7 [early endosome membrane]
# UniProt | P01889 | class I MHC B7 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P01889 | class I MHC B7 [phagocytic vesicle membrane]
# UniProt | P01889 | class I MHC B7 [plasma membrane]
# UniProt | P01889 | class I MHC B7 [recycling endosome membrane]
# UniProt | Q31612 | class I MHC B73 [ER to Golgi transport vesicle membrane]
# UniProt | Q31612 | class I MHC B73 [Golgi membrane]
# UniProt | Q31612 | class I MHC B73 [early endosome membrane]
# UniProt | Q31612 | class I MHC B73 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q31612 | class I MHC B73 [phagocytic vesicle membrane]
# UniProt | Q31612 | class I MHC B73 [plasma membrane]
# UniProt | Q31612 | class I MHC B73 [recycling endosome membrane]
# UniProt | P30498 | class I MHC B78 [ER to Golgi transport vesicle membrane]
# UniProt | P30498 | class I MHC B78 [Golgi membrane]
# UniProt | P30498 | class I MHC B78 [early endosome membrane]
# UniProt | P30498 | class I MHC B78 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30498 | class I MHC B78 [phagocytic vesicle membrane]
# UniProt | P30498 | class I MHC B78 [plasma membrane]
# UniProt | P30498 | class I MHC B78 [recycling endosome membrane]
# UniProt | P30460 | class I MHC B8 [ER to Golgi transport vesicle membrane]
# UniProt | P30460 | class I MHC B8 [Golgi membrane]
# UniProt | P30460 | class I MHC B8 [early endosome membrane]
# UniProt | P30460 | class I MHC B8 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | P30460 | class I MHC B8 [phagocytic vesicle membrane]
# UniProt | P30460 | class I MHC B8 [plasma membrane]
# UniProt | P30460 | class I MHC B8 [recycling endosome membrane]
# UniProt | Q31610 | class I MHC B81 [ER to Golgi transport vesicle membrane]
# UniProt | Q31610 | class I MHC B81 [Golgi membrane]
# UniProt | Q31610 | class I MHC B81 [early endosome membrane]
# UniProt | Q31610 | class I MHC B81 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q31610 | class I MHC B81 [phagocytic vesicle membrane]
# UniProt | Q31610 | class I MHC B81 [plasma membrane]
# UniProt | Q31610 | class I MHC B81 [recycling endosome membrane]
# UniProt | Q29718 | class I MHC B82 [ER to Golgi transport vesicle membrane]
# UniProt | Q29718 | class I MHC B82 [Golgi membrane]
# UniProt | Q29718 | class I MHC B82 [early endosome membrane]
# UniProt | Q29718 | class I MHC B82 [integral component of lumenal side of endoplasmic reticulum membrane]
# UniProt | Q29718 | class I MHC B82 [phagocytic vesicle membrane]
# UniProt | Q29718 | class I MHC B82 [plasma membrane]
# UniProt | Q29718 | class I MHC B82 [recycling endosome membrane]
# UniProt | P26623 | mip [extracellular region]
# UniProt | P58753 | p-4Y-TIRAP [plasma membrane]
# UniProt | P14598 | p-6S-NCF1 [phagolysosome]
# UniProt | O00161 | p-S95-SNAP23 [phagocytic vesicle membrane]
# UniProt | Q15080 | p-T154,S315-NCF4 [phagolysosome]
# UniProt | P19878 | p-T233-NCF2 [phagolysosome]

# %% [markdown]
# Copyright (C) 2018-present, DV Klopfenstein. All rights reserved.
